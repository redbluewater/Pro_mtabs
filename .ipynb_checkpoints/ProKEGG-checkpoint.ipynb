# %% [markdown]
# #Chisholm / Prochlorococcus project
# ##Use Python and its various libraries to link the KEGG compound information with pathways
# ###KLongnecker, 4/17/2017

# %%
if True:
    # %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import pandas as pd
import numpy as np
import re
import os
import glob
import math
from imp import reload
import pdb

import palettable as pal
import matplotlib.pyplot as plt
import matplotlib as mpl 
mpl.rcParams['pdf.fonttype'] = 42

from Bio import SeqIO
from Bio.KEGG.REST import *
from Bio.KEGG.KGML import KGML_parser
from Bio.Graphics.KGML_vis import KGMLCanvas
from IPython.display import Image, HTML

#used this to step into the function and debug it, also need line with Tracer()() 
from IPython.core.debugger import Tracer 
#os._exit(1) #this should get me out of the debugging...

# %matplotlib inline

# %%
mtabFile = 'ChisholmPro_cellSpecific_KEGGexport.2017.04.20_v2.csv' #first column is KEGG C number
mtabData=pd.read_csv(mtabFile, index_col='KEGG')
mtabData.head()
# Out:
#                              mtabNames  extEff  \
# KEGG
# C00196       2-3-dihydroxybenzoic acid   100.9
# C19675  2-3-dihydroxypropane1sulfonate     0.6
# C08276          3-mercapto proprionate    88.6
# C00141     3-methyl-2-oxobutanoic acid     NaN
# C00671    3-methyl-2-oxopentanoic acid     NaN
#
#         Plimited_extracellular_s9301ax_50  Plimited_filter_s9301ax_50  \
# KEGG
# C00196                       0.000000e+00                         0.0
# C19675                       1.502503e-09                         0.0
# C08276                       0.000000e+00                         0.0
# C00141                       1.501737e-07                         0.0
# C00671                       0.000000e+00                         0.0
#
#         replete_extracellular_s9301ax_10  replete_extracellular_s9301ax_50  \
# KEGG
# C00196                      0.000000e+00                      0.000000e+00
# C19675                      7.559786e-09                      0.000000e+00
# C08276                      0.000000e+00                      0.000000e+00
# C00141                      1.269247e-07                      1.719122e-07
# C00671                      5.760611e-08                      1.074612e-07
#
#         replete_extracellular_s0801ax_10  replete_extracellular_s9313ax_5  \
# KEGG
# C00196                      0.000000e+00                     0.000000e+00
# C19675                      8.830372e-09                     0.000000e+00
# C08276                      0.000000e+00                     0.000000e+00
# C00141                      3.699587e-09                     1.385979e-06
# C00671                      0.000000e+00                     3.044114e-07
#
#         replete_extracellular_s9313ax_10  replete_filter_s9301ax_10  \
# KEGG
# C00196                      0.000000e+00               0.000000e+00
# C19675                      0.000000e+00               0.000000e+00
# C08276                      0.000000e+00               0.000000e+00
# C00141                      1.185440e-06               0.000000e+00
# C00671                      3.038489e-07               1.499082e-09
#
#         replete_filter_s9301ax_50  replete_filter_s0801ax_10  \
# KEGG
# C00196               0.000000e+00               0.000000e+00
# C19675               0.000000e+00               0.000000e+00
# C08276               0.000000e+00               0.000000e+00
# C00141               0.000000e+00               0.000000e+00
# C00671               1.232101e-09               2.171711e-09
#
#         replete_filter_s9313ax_5  replete_filter_s9313ax_10
# KEGG
# C00196              0.000000e+00               0.000000e+00
# C19675              0.000000e+00               0.000000e+00
# C08276              0.000000e+00               0.000000e+00
# C00141              0.000000e+00               0.000000e+00
# C00671              1.414847e-10               2.189543e-09

# %%
#take out the extra columns: 
mtabData.drop(['extEff','mtabNames'],axis = 1,inplace = True)
mtabData.head()
# Out:
#         Plimited_extracellular_s9301ax_50  Plimited_filter_s9301ax_50  \
# KEGG
# C00196                       0.000000e+00                         0.0
# C19675                       1.502503e-09                         0.0
# C08276                       0.000000e+00                         0.0
# C00141                       1.501737e-07                         0.0
# C00671                       0.000000e+00                         0.0
#
#         replete_extracellular_s9301ax_10  replete_extracellular_s9301ax_50  \
# KEGG
# C00196                      0.000000e+00                      0.000000e+00
# C19675                      7.559786e-09                      0.000000e+00
# C08276                      0.000000e+00                      0.000000e+00
# C00141                      1.269247e-07                      1.719122e-07
# C00671                      5.760611e-08                      1.074612e-07
#
#         replete_extracellular_s0801ax_10  replete_extracellular_s9313ax_5  \
# KEGG
# C00196                      0.000000e+00                     0.000000e+00
# C19675                      8.830372e-09                     0.000000e+00
# C08276                      0.000000e+00                     0.000000e+00
# C00141                      3.699587e-09                     1.385979e-06
# C00671                      0.000000e+00                     3.044114e-07
#
#         replete_extracellular_s9313ax_10  replete_filter_s9301ax_10  \
# KEGG
# C00196                      0.000000e+00               0.000000e+00
# C19675                      0.000000e+00               0.000000e+00
# C08276                      0.000000e+00               0.000000e+00
# C00141                      1.185440e-06               0.000000e+00
# C00671                      3.038489e-07               1.499082e-09
#
#         replete_filter_s9301ax_50  replete_filter_s0801ax_10  \
# KEGG
# C00196               0.000000e+00               0.000000e+00
# C19675               0.000000e+00               0.000000e+00
# C08276               0.000000e+00               0.000000e+00
# C00141               0.000000e+00               0.000000e+00
# C00671               1.232101e-09               2.171711e-09
#
#         replete_filter_s9313ax_5  replete_filter_s9313ax_10
# KEGG
# C00196              0.000000e+00               0.000000e+00
# C19675              0.000000e+00               0.000000e+00
# C08276              0.000000e+00               0.000000e+00
# C00141              0.000000e+00               0.000000e+00
# C00671              1.414847e-10               2.189543e-09

# %%
#allPathways = kegg_list("pathway").read() #all organisms
#pmg is 9301, HLII, #pmt is 9313, LLIV, #prm is 0801, LLI
oneStrain = 'pmg' #use later as well
allPathways = kegg_list("pathway",oneStrain).read() 

len(allPathways.split('\n'))
# Out:
# 99

# %%
trimPath = []
current_section = None
for line in allPathways.rstrip().split("\n"):
    tp = line[5:13]
    trimPath.append(tp)

# %%
#set up a function to get the list of compounds for a given pathway (must be defined as ko00140 NOT map00140)
def getCfrom_ko(ko_id):
    pathway_file = kegg_get(ko_id).read()  # query and read the pathway
    compound_list = []

    current_section = None
    for line in pathway_file.rstrip().split("\n"):
        section = line[:12].strip()  # section names are within 12 columns
        if not section == "":
            current_section = section
        if current_section == "COMPOUND":
            compound_identifiers = line[12:].split("; ")
            t = compound_identifiers[0]
            compound_id = t[0:6]

            if not compound_id in compound_list:
                compound_list.append(compound_id)
    return compound_list

# %%
#set up a function to get the list of K orthologues for a given pathway (must be defined as ko00140 NOT map00140)
#for this project: can use the three digit code for the different Prochlorococcus strains
def getKfrom_ko(ko_id):
    pathway_file = kegg_get(ko_id).read()  # query and read the pathway
    K_list = []

    current_section = None
    for line in pathway_file.rstrip().split("\n"):
        section = line[:12].strip()  # section names are within 12 columns
        if not section == "":
            current_section = section
        if current_section == "ORTHOLOGY":
            K_identifiers = line[12:].split("; ")
            t = K_identifiers[0]
            K_id = t[0:6]

            if not K_id in K_list:
                K_list.append(K_id)
    return K_list

# %%
# A bit of code that will help us display the PDF output
def PDF(filename):
    return HTML('<iframe src=%s width=700 height=350></iframe>' % filename)

# %%
#bring in the plotting functions
import plotByGroup
import fxn_plotPathway
##if I make a change, have to reload the function(s):
# reload(fxn_plotPathway)

# %%
#have zeros for metabolites that are not in KEGG, need to delete the zeros for now...
mtabPruned = mtabData.drop(['0'])

# %%
if False:
    #do all pathways
    for item in trimPath:
        fxn_plotPathway.gatherDetails(item,useFolder,useCO,CO_values)

# %%
#organize pathways into the groups defined in the BRITE file
def ReadBRITEfile(briteFile):
    forBrite = pd.DataFrame(columns = ['map','A','B','C','wholeThing'])
    # set up the expressions to match each level in the BRITE hierarchy
    
    textA = re.compile(r'(^A<b>)(.+)(</b>)\s*(.*)$')
    textB = re.compile(r'(^B)\s*(.*)$')
    textC = re.compile(r'(\d+)\s*(.*)$')
    #this relies on the fact that the rows are in order: A, with B subheadings, then C subheadings
    setA = []
    idxA = []

    setB = []
    setC = []

    with open(briteFile) as f:
        for idx,line in enumerate(f):
            if line[0] is not '#': #skip over the comments
                mA = textA.search(line) 
                mB = textB.search(line) 
                mC = textC.search(line) 
                if mA:
                    setA = mA.group(2)
                    #house cleaning (probably c)
                    idxA = idx
                    forBrite.loc[idx,'A'] = setA
                    forBrite.loc[idx,'wholeThing'] = line #using this as a double check for now
                    #forBrite.loc[idx,'map'] = mC.group(1)
                elif mB:
                    setB = mB.group(2)
                    forBrite.loc[idx,'A'] = setA
                    forBrite.loc[idx,'B'] = setB
                    forBrite.loc[idx,'wholeThing'] = line
                    #forBrite.loc[idx,'map'] = mC.group(1)
                elif mC:
                    #Tracer()()
                    setC = mC.group(2)
                    forBrite.loc[idx,'A'] = setA
                    forBrite.loc[idx,'B'] = setB
                    forBrite.loc[idx,'C'] = setC
                    forBrite.loc[idx,'wholeThing'] = line
                    forBrite.loc[idx,'map'] = mC.group(1)

    return forBrite

# %%
#go read in the file from KEGG
D = glob.glob('br08901.keg') #from http://www.genome.jp/kegg-bin/get_htext?br08901.keg; 4/18/2017
allBRITE=[]
for idx,nof in enumerate(D):
    allBRITE = ReadBRITEfile(nof)
    
prunedBRITE = allBRITE.dropna()
prunedBRITE.head()
# Out:
#       map           A                         B  \
# 10  01100  Metabolism  Global and overview maps
# 11  01110  Metabolism  Global and overview maps
# 12  01120  Metabolism  Global and overview maps
# 13  01130  Metabolism  Global and overview maps
# 14  01200  Metabolism  Global and overview maps
#
#                                                C  \
# 10                            Metabolic pathways
# 11         Biosynthesis of secondary metabolites
# 12  Microbial metabolism in diverse environments
# 13                   Biosynthesis of antibiotics
# 14                             Carbon metabolism
#
#                                            wholeThing
# 10                   C    01100  Metabolic pathways\n
# 11  C    01110  Biosynthesis of secondary metaboli...
# 12  C    01120  Microbial metabolism in diverse en...
# 13          C    01130  Biosynthesis of antibiotics\n
# 14                    C    01200  Carbon metabolism\n

# %%
#probably a way to do this in one step...only want 'metabolism' biochemical pathways
findM = prunedBRITE.loc[(prunedBRITE['A'] == 'Metabolism')]
findU = findM.loc[:,'B']

#really not that many pathway groups
findU.unique()
# Out:
# array(['Global and overview maps', 'Carbohydrate metabolism',
#        'Energy metabolism', 'Lipid metabolism', 'Nucleotide metabolism',
#        'Amino acid metabolism', 'Metabolism of other amino acids',
#        'Glycan biosynthesis and metabolism',
#        'Metabolism of cofactors and vitamins',
#        'Metabolism of terpenoids and polyketides',
#        'Biosynthesis of other secondary metabolites',
#        'Xenobiotics biodegradation and metabolism',
#        'Chemical structure transformation maps'], dtype=object)

# %%
unMetabolismGroups = findU.unique()
unMetabolismGroups = np.delete(unMetabolismGroups,(0),axis=0) #skip over the global and overview maps

# %%
#now that I have the colors all set...let's think about what we actually want to plot...
list(mtabPruned)
# Out:
# ['Plimited_extracellular_s9301ax_50',
#  'Plimited_filter_s9301ax_50',
#  'replete_extracellular_s9301ax_10',
#  'replete_extracellular_s9301ax_50',
#  'replete_extracellular_s0801ax_10',
#  'replete_extracellular_s9313ax_5',
#  'replete_extracellular_s9313ax_10',
#  'replete_filter_s9301ax_10',
#  'replete_filter_s9301ax_50',
#  'replete_filter_s0801ax_10',
#  'replete_filter_s9313ax_5',
#  'replete_filter_s9313ax_10']

# %%
#oneStrain = 'pmg' #run for one strain that has been set above(options are 'pmg','pmt','prm')
useCO = mtabPruned.index
#these are the data (or ratios to plot...)
CO_values = mtabPruned.loc[:,'Plimited_filter_s9301ax_50']/mtabPruned.loc[:,'replete_filter_s9301ax_50']

# %%
import colorbar_only

# %%
reload(colorbar_only)
#this will be the range of colors in the pathway maps (not green bc genes are green)
# Out:
# <module 'colorbar_only' from 'C:\\Users\\krista\\Documents\\GitHub\\Pro_mtabs\\colorbar_only.py'>

# %%
if True:
    ##this will take a while...
    for oneGroup in unMetabolismGroups:
        shortList = prunedBRITE.loc[(prunedBRITE['B']==oneGroup)] 
        onePath = shortList.loc[:,'map']
        onePath_ann = []
        for item in onePath:
            onePath_ann.append(oneStrain + item)

        #plot pathways divided by group, remember...can have pathways not annotated for this Pro strain
        for runOne in onePath_ann:    
            try:
                fxn_plotPathway.gatherDetails(runOne,oneGroup,useCO,CO_values)               
            except:
                print('problem with this pathway ' + item)

        #next line will make the color maps for each group: purple = low; green = high
        plotByGroup.plotGroup(oneGroup,prunedBRITE,useCO,mtabPruned,oneStrain)
# Out:
# problem with this pathway 00983
# problem with this pathway 01070
# problem with this pathway 01070
# problem with this pathway 01070
# problem with this pathway 01070
# problem with this pathway 01070
# problem with this pathway 01070
# problem with this pathway 01070
# problem with this pathway 01070
# problem with this pathway 01070

# %%
#make a list....and remove the three digit header bc that will be unique to each strain
def trimPath(pathwayString):
    export_trimPath = []
    current_section = None
    for line in pathwayString.rstrip().split("\n"):
        #tp = line[5:13] #this includes the three digit species code
        tp = line[8:13]
        export_trimPath.append(tp)
    return export_trimPath

# %%
from matplotlib_venn import venn2
from matplotlib_venn import venn3
from matplotlib_venn import venn3_unweighted

# %%
pmgPathways = kegg_list('pathway','pmg').read()
pmgTrim = trimPath(pmgPathways)

# %%
prmPathways = kegg_list('pathway','prm').read()
prmTrim = trimPath(prmPathways)

# %%
pmtPathways = kegg_list('pathway','pmt').read()
pmtTrim = trimPath(pmtPathways)

# %%
#what about set different?
def diff(list1, list2):
    c = set(list1).union(set(list2))
    d = set(list1).intersection(set(list2))
    return list(c - d)

# %%
out = diff(pmtTrim, pmgTrim)

# %%
inTwo = set(pmgTrim).intersection(set(prmTrim))
d = set(pmgTrim).difference(set(prmTrim))

# %%
venn3_unweighted(subsets = (set(pmgTrim),set(prmTrim),set(pmtTrim)))

# %%
#make a list....and remove the three digit header bc that will be unique to each strain
def trimPath(pathwayString):
    export_trimPath = []
    current_section = None
    for line in pathwayString.rstrip().split("\n"):
        #tp = line[5:13] #this includes the three digit species code
        tp = line[8:13]
        export_trimPath.append(tp)
    return export_trimPath

# %%
#make a list....and remove the three digit header bc that will be unique to each strain
def trimGenes(geneString):
    export_trimGenes = []
    current_section = None
    for line in geneString.rstrip().split("\n"):
        #tp = line[5:13] #this includes the three digit species code
        r = line.find('ko:')
        tp = line[r+3 : r+9]
        export_trimGenes.append(tp)
    return export_trimGenes

# %%
#pull the full set of genes for each strain...
pmtGenes = kegg_link("ko","pmt").read()
pmtGenes = trimGenes(pmtGenes)

# %%
#pull the full set of genes for each strain...
pmgGenes = kegg_link("ko","pmg").read()
pmgGenes = trimGenes(pmgGenes)

# %%
#pull the full set of genes for each strain...can do this in one step...
prmGenes = trimGenes(kegg_link("ko","prm").read())

# %%
#pull the full set of compounds for each strain...
#have to loop through because the KEGG / REST code will not do this

# %%
#setup the strings to match first
rnString = re.compile('(?:[rn:R])(\d+)$') #will return R00190
cpdString = re.compile('(?:[cpd:C])(\d+)$') #will return C00190

pmg_countCpd = []
pmg_countGene = []
pmg_countRxn = []
        
for gen in pmgGenes: #go through each gene...one at a time
    rnList = kegg_link('reaction',gen).read() #get the list of reactions for that gene
    #can have cases where there is a gene and no reaction (K02906 for example). This returns rnList = '\n'
    #since this is not actually empty...need a few way to filter those out
    test = '\n'
    if test != rnList:
        for line in rnList.rstrip().split('\n'):
            m = rnString.search(line) #get the reaction number
            pmg_countRxn.append(m.group(0))
            cpdList = kegg_link('cpd',m.group(0)).read() #now go get the compounds for that reaction
            del m #have to do this so I can pickle the whole thing later...
            #can have no compounds in a reaction (only glycans, begin with G, nothing I have matched)
            if len(cpdList) > 1: #will be true if cpdList includes compounds
                for line2 in cpdList.rstrip().split('\n'):
                    m2 = cpdString.search(line2).group(0)
                    pmg_countCpd.append(m2) 
                    pmg_countGene.append(gen)

# %%
pmt_countCpd = []
pmt_countGene = []
pmt_countRxn = []

for gen in pmtGenes: #go through each gene...one at a time
    rnList = kegg_link('reaction',gen).read() #get the list of reactions for that gene
    #can have cases where there is a gene and no reaction (K02906 for example). This returns rnList = '\n'
    #since this is not actually empty...need a few way to filter those out
    test = '\n'
    if test != rnList:
        for line in rnList.rstrip().split('\n'):
            m = rnString.search(line) #get the reaction number
            pmt_countRxn.append(m.group(0))
            cpdList = kegg_link('cpd',m.group(0)).read() #now go get the compounds for that reaction
            del m #have to do this so I can pickle the whole thing later...
            #can have no compounds in a reaction (only glycans, begin with G, nothing I have matched)
            if len(cpdList) > 1: #will be true if cpdList includes compounds
                for line2 in cpdList.rstrip().split('\n'):
                    m2 = cpdString.search(line2).group(0)
                    pmt_countCpd.append(m2) 
                    pmt_countGene.append(gen)

# %%
prm_countCpd = []
prm_countGene = []
prm_countRxn = []

for gen in prmGenes: #go through each gene...one at a time
    rnList = kegg_link('reaction',gen).read() #get the list of reactions for that gene
    #can have cases where there is a gene and no reaction (K02906 for example). This returns rnList = '\n'
    #since this is not actually empty...need a few way to filter those out
    test = '\n'
    if test != rnList:
        for line in rnList.rstrip().split('\n'):
            m = rnString.search(line) #get the reaction number
            prm_countRxn.append(m.group(0))
            cpdList = kegg_link('cpd',m.group(0)).read() #now go get the compounds for that reaction
            del m #have to do this so I can pickle the whole thing later...
            #can have no compounds in a reaction (only glycans, begin with G, nothing I have matched)
            if len(cpdList) > 1: #will be true if cpdList includes compounds
                for line2 in cpdList.rstrip().split('\n'):
                    m2 = cpdString.search(line2).group(0)
                    prm_countCpd.append(m2) 
                    prm_countGene.append(gen)

# %%
#now, consider the overlap in compounds among the three strains

# %%
venn3_unweighted(subsets = (set(pmg_countCpd),set(prm_countCpd),set(pmt_countCpd)),set_labels = 
                 ('pmg','prm','pmt'))
plt.title('This is the set of compounds for the three strains')
#plt.show() #don't do this...this creates a new figure
plt.savefig('Pro_cpds.png')

# %%
v = venn3_unweighted(subsets = (set(pmg_countGene),set(prm_countGene),set(pmt_countGene)),set_labels = 
                 ('pmg','prm','pmt'))

# %%
v = venn3_unweighted(subsets = (set(pmg_countRxn),set(prm_countRxn),set(pmt_countRxn)),set_labels = 
                 ('pmg','prm','pmt'))
plt.title('This is the set of reactions for the three strains')
#plt.show() #don't do this...this creates a new figure
plt.savefig('testing.png')

# %%
len(set(pmg_countGene) & set(prm_countGene)- set(pmt_countGene))
# Out:
# 11

# %%
len(set(pmg_countGene) & set(pmt_countGene)- set(prm_countGene))
# Out:
# 17

# %%
len(set(prm_countGene) - (set(pmg_countGene)| set(pmt_countGene)))
# Out:
# 7

# %%
#...ok, have convinced myself I get this...

# %%
set(prm_countGene) - (set(pmg_countGene)| set(pmt_countGene))
# Out:
# {'K00101', 'K00978', 'K01623', 'K01709', 'K01725', 'K01953', 'K18827'}

# %%
set(prm_countCpd) - (set(pmg_countCpd)| set(pmt_countCpd))
# Out:
# {'C00186', 'C00501', 'C01219', 'C01417', 'C20761', 'C20762', 'C20763'}

# %%
len(set(prm_countRxn) - (set(pmg_countRxn)| set(pmt_countRxn)))
# Out:
# 8

# %%
rxnString = set(prm_countRxn) - (set(pmg_countRxn)| set(pmt_countRxn))
#rxnString = set(pmg_countRxn) - (set(prm_countRxn)| set(pmt_countRxn))
#rxnString = set(pmt_countRxn) - (set(prm_countRxn)| set(pmg_countRxn))

# %%
for line in rxnString:
    #print(line)
    print(kegg_get(line).read())
# Out:
# ENTRY       R03546                      Reaction
# NAME        carbamate hydro-lyase;
#             cyanate hydratase;
#             cyanate C-N-lyase
# DEFINITION  Cyanate + H+ + HCO3- <=> CO2 + Carbamate
# EQUATION    C01417 + C00080 + C00288 <=> C00011 + C01563
# COMMENT     first step of two-step reaction (see R10079, R03546+R07316)
#             bicarbonate is recycled (see R10092)
# RCLASS      RC00952  C01417_C01563
#             RC02807  C00011_C00288
# ENZYME      4.2.1.104
# PATHWAY     rn00910  Nitrogen metabolism
# ORTHOLOGY   K01725  cyanate lyase [EC:4.2.1.104]
# REFERENCE   1  [PMID:3110153]
#             Johnson WV, Anderson PM.
#             Bicarbonate is a recycling substrate for cyanase.
#             J. Biol. Chem. 262 (1987) 9021-5.
#             2  [PMID:7947823]
#             Anderson PM, Korte JJ, Holcomb TA.
#             Reaction of the N-terminal methionine residues in cyanase with diethylpyrocarbonate.
#             Biochemistry. 33 (1994) 14121-5.
# ///
#
# ENTRY       R10657                      Reaction
# NAME        ATP:alpha-D-Man-(1->2)-alpha-D-Man-(1->2)-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)-[alpha-D-Man-(1->2)-alpha-D-Man-(1->2)-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)]n-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)-alpha-D-GlcNAc-diphospho-ditrans,octacis-undecaprenol 3-phosphotransferase
# DEFINITION  ATP + alpha-D-Man-(1->2)-alpha-D-Man-(1->2)-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)-[alpha-D-Man-(1->2)-alpha-D-Man-(1->2)-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)]n-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)-alpha-D-GlcNAc-diphospho-ditrans,octacis-undecaprenol <=> ADP + 3-O-Phospho-alpha-D-Man-(1->2)-alpha-D-Man-(1->2)-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)-[alpha-D-Man-(1->2)-alpha-D-Man-(1->2)-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)]n-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)-alpha-D-GlcNAc-diphospho-ditrans,octacis-undecaprenol
# EQUATION    C00002 + C20761 <=> C00008 + C20762
# RCLASS      RC00002  C00002_C00008
#             RC00078  C20761_C20762
# ENZYME      2.7.1.181
# ORTHOLOGY   K18827  O-antigen chain-terminating methyltransferase [EC:2.1.1.- 2.1.1.294 2.7.1.181]
# ///
#
# ENTRY       R02426                      Reaction
# NAME        CDPglucose 4,6-hydro-lyase
# DEFINITION  CDP-glucose <=> CDP-4-dehydro-6-deoxy-D-glucose + H2O
# EQUATION    C00501 <=> C01219 + C00001
# RCLASS      RC00402  C00501_C01219
# ENZYME      4.2.1.45
# PATHWAY     rn00520  Amino sugar and nucleotide sugar metabolism
# ORTHOLOGY   K01709  CDP-glucose 4,6-dehydratase [EC:4.2.1.45]
# ///
#
# ENTRY       R10079                      Reaction
# NAME        carbamate hydro-lyase;
#             cyanate hydratase
# DEFINITION  Cyanate + HCO3- + H+ <=> Ammonia + 2 CO2
# EQUATION    C01417 + C00288 + C00080 <=> C00014 + 2 C00011
# COMMENT     two-step reaction (see R03546+R07316)
#             bicarbonate is recycled (see R10092)
# RCLASS      RC02807  C00011_C00288
# ENZYME      4.2.1.104
# ORTHOLOGY   K01725  cyanate lyase [EC:4.2.1.104]
# ///
#
# ENTRY       R00196                      Reaction
# NAME        (S)-Lactate:ferricytochrome-c 2-oxidoreductase
# DEFINITION  (S)-Lactate + 2 Ferricytochrome c <=> Pyruvate + 2 Ferrocytochrome c + 2 H+
# EQUATION    C00186 + 2 C00125 <=> C00022 + 2 C00126 + 2 C00080
# RCLASS      RC00016  C00125_C00126
#             RC00044  C00022_C00186
# ENZYME      1.1.2.3
# PATHWAY     rn00620  Pyruvate metabolism
#             rn01100  Metabolic pathways
# ORTHOLOGY   K00101  L-lactate dehydrogenase (cytochrome) [EC:1.1.2.3]
# ///
#
# ENTRY       R00578                      Reaction
# NAME        L-aspartate:L-glutamine amido-ligase (AMP-forming)
# DEFINITION  ATP + L-Aspartate + L-Glutamine + H2O <=> AMP + Diphosphate + L-Asparagine + L-Glutamate
# EQUATION    C00002 + C00049 + C00064 + C00001 <=> C00020 + C00013 + C00152 + C00025
# COMMENT     two-step reaction (see R00256+R00483)
# RCLASS      RC00010  C00025_C00064  C00049_C00152
# ENZYME      6.3.5.4
# PATHWAY     rn00250  Alanine, aspartate and glutamate metabolism
#             rn01100  Metabolic pathways
#             rn01110  Biosynthesis of secondary metabolites
# ORTHOLOGY   K01953  asparagine synthase (glutamine-hydrolysing) [EC:6.3.5.4]
# ///
#
# ENTRY       R10658                      Reaction
# NAME        S-adenosyl-L-methionine:3-O-phospho-alpha-D-Man-(1->2)-alpha-D-Man-(1->2)-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)-[alpha-D-Man-(1->2)-alpha-D-Man-(1->2)-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)]n-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)-alpha-D-GlcNAc-alpha-diphospho-ditrans,octacis-undecaprenol 3-phospho-methyltransferase
# DEFINITION  S-Adenosyl-L-methionine + 3-O-Phospho-alpha-D-Man-(1->2)-alpha-D-Man-(1->2)-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)-[alpha-D-Man-(1->2)-alpha-D-Man-(1->2)-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)]n-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)-alpha-D-GlcNAc-diphospho-ditrans,octacis-undecaprenol <=> S-Adenosyl-L-homocysteine + 3-O-Methylphospho-alpha-D-Man-(1->2)-alpha-D-Man-(1->2)-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)-[alpha-D-Man-(1->2)-alpha-D-Man-(1->2)-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)]n-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)-alpha-D-GlcNAc-diphospho-ditrans,octacis-undecaprenol
# EQUATION    C00019 + C20762 <=> C00021 + C20763
# RCLASS      RC00003  C00019_C00021
#             RC03220  C20762_C20763
# ENZYME      2.1.1.294
# ORTHOLOGY   K18827  O-antigen chain-terminating methyltransferase [EC:2.1.1.- 2.1.1.294 2.7.1.181]
# ///
#
# ENTRY       R00956                      Reaction
# NAME        CTP:alpha-D-glucose-1-phosphate cytidylyltransferase
# DEFINITION  CTP + D-Glucose 1-phosphate <=> Diphosphate + CDP-glucose
# EQUATION    C00063 + C00103 <=> C00013 + C00501
# RCLASS      RC00002  C00103_C00501
# ENZYME      2.7.7.33
# PATHWAY     rn00500  Starch and sucrose metabolism
#             rn00520  Amino sugar and nucleotide sugar metabolism
#             rn01100  Metabolic pathways
# ORTHOLOGY   K00978  glucose-1-phosphate cytidylyltransferase [EC:2.7.7.33]
# ///

# %%
cpdString = set(prm_countCpd) - (set(pmg_countCpd)| set(pmt_countCpd))
for item in cpdString:
    print(kegg_list(item).read())
# Out:
# cpd:C20762	3-O-Phospho-alpha-D-Man-(1->2)-alpha-D-Man-(1->2)-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)-[alpha-D-Man-(1->2)-alpha-D-Man-(1->2)-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)]n-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)-alpha-D-GlcNAc-diphospho-ditrans,octacis-undecaprenol
#
# cpd:C20761	alpha-D-Man-(1->2)-alpha-D-Man-(1->2)-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)-[alpha-D-Man-(1->2)-alpha-D-Man-(1->2)-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)]n-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)-alpha-D-GlcNAc-diphospho-ditrans,octacis-undecaprenol
#
# cpd:C01219	CDP-4-dehydro-6-deoxy-D-glucose
#
# cpd:C20763	3-O-Methylphospho-alpha-D-Man-(1->2)-alpha-D-Man-(1->2)-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)-[alpha-D-Man-(1->2)-alpha-D-Man-(1->2)-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)]n-alpha-D-Man-(1->3)-alpha-D-Man-(1->3)-alpha-D-GlcNAc-diphospho-ditrans,octacis-undecaprenol
#
# cpd:C00501	CDP-glucose; CDP-D-Glucose
#
# cpd:C00186	(S)-Lactate; L-Lactate; L-Lactic acid
#
# cpd:C01417	Cyanate; Cyanic acid

# %%
cpdString = set(pmg_countCpd) - (set(prm_countCpd)| set(pmt_countCpd))
for item in cpdString:
    print(kegg_list(item).read())
# Out:
# cpd:C00645	N-Acetyl-D-mannosamine; 2-Acetamido-2-deoxy-D-mannose
#
# cpd:C01146	2-Hydroxy-3-oxopropanoate; Tartronate semialdehyde
#
# cpd:C03440	cis-4-Hydroxy-D-proline
#
# cpd:C04294	5-(2-Hydroxyethyl)-4-methylthiazole; 4-Methyl-5-(2'-hydroxyethyl)-thiazole; 4-Methyl-5-(2-hydroxyethyl)-thiazole
#
# cpd:C00511	Acrylic acid; Propenoate; Acrylate; 2-Propenoic acid; Vinylformic acid
#
# cpd:C00515	D-Ornithine
#
# cpd:C01279	4-Amino-5-hydroxymethyl-2-methylpyrimidine; Toxopyrimidine; 4-Amino-2-methyl-5-pyrimidinemethanol
#
# cpd:C05714	alpha-Aminopropiononitrile
#
# cpd:C20267	4-Amino-5-aminomethyl-2-methylpyrimidine
#
# cpd:C16074	Phenylacetonitrile; Benzyl cyanide
#
# cpd:C00180	Benzoate; Benzoic acid; Benzenecarboxylic acid; Phenylformic acid; Dracylic acid
#
# cpd:C03410	N-Glycoloyl-neuraminate; N-Glycolylneuraminate; Neu5Gc
#
# cpd:C03564	1-Pyrroline-2-carboxylate; 1-Pyrroline-2-carboxylic acid; Delta1-Pyrroline 2-carboxylate; 1-Pyrroline 2-carboxylate
#
# cpd:C00128	CMP-N-acetylneuraminate; CMP-N-acetyl-beta-neuraminate
#
# cpd:C03691	CMP-N-glycoloylneuraminate; CMP-N-glycolylneuraminate; CMP-Neu5Gc
#
# cpd:C09814	Benzonitrile; Phenyl cyanide; Cyanobenzene
#
# cpd:C05678	(2-Amino-1-hydroxyethyl)phosphonate; 1-Hydroxy-2-aminoethylphosphonate
#
# cpd:C00282	Hydrogen; H2
#
# cpd:C00325	GDP-L-fucose; GDP-beta-L-fucose
#
# cpd:C04282	1-Pyrroline-4-hydroxy-2-carboxylate
#
# cpd:C07086	Phenylacetic acid; Benzylformic acid; Phenylacetate; Benzeneacetic acid
#
# cpd:C06241	N-Acetylneuraminate 9-phosphate
#
# cpd:C03921	2-Dehydro-3-deoxy-D-glucarate
#
# cpd:C00679	5-Dehydro-4-deoxy-D-glucarate; (2R,3S)-2,3-Dihydroxy-5-oxohexanedioate
#
# cpd:C00792	D-Arginine; D-2-Amino-5-guanidinovaleric acid
#
# cpd:C03557	2-Aminoethylphosphonate; (2-Aminoethyl)phosphonate; Ciliatine
#
# cpd:C04712	(7R)-7-(5-Carboxy-5-oxopentanoyl)aminocephalosporinate
#
# cpd:C03539	S-Ribosyl-L-homocysteine; S-D-Ribosyl-L-homocysteine; Ribose-5-S-homocysteine; S-Ribosylhomocysteine; S-(5-Deoxy-D-ribos-5-yl)-L-homocysteine
#
# cpd:C00916	Cephalosporin C
#
# cpd:C01998	Acrylonitrile; Propenenitrile; Vinyl cyanide
#
# cpd:C00726	Nitrile; R-CN
#
# cpd:C19878	D-glycero-alpha-D-manno-Heptose 7-phosphate
#
# cpd:C03771	5-Guanidino-2-oxopentanoate; 5-Guanidino-2-oxo-pentanoate; 2-Oxo-5-guanidinopentanoate; 2-Oxo-5-guanidino-pentanoate; 2-Oxoarginine
#
# cpd:C19882	D-glycero-D-manno-Heptose 7-phosphate
#
# cpd:C00763	D-Proline
#
# cpd:C01110	5-Amino-2-oxopentanoic acid; 5-Amino-2-oxopentanoate; 2-Oxo-5-amino-pentanoate; 2-Oxo-5-aminopentanoate; alpha-Keto-delta-aminopentanoate; 2-Oxo-5-aminovalerate
#
# cpd:C01401	Alanine; 2-Aminopropionic acid; 2-Aminopropanoic acid
#
# cpd:C03089	5-Methylthio-D-ribose; S-Methyl-5-thio-D-ribose
#
# cpd:C00270	N-Acetylneuraminate; N-Acetylneuraminic acid; 5-Acetamido-3,5-dideoxy-D-glycero-D-galacto-2-nonulosonic acid; Neu5Ac
#
# cpd:C07836	D-glycero-beta-D-manno-Heptose 7-phosphate
#
# cpd:C05715	gamma-Amino-gamma-cyanobutanoate; 4-Amino-4-cyanobutanoic acid
#
# cpd:C02938	3-Indoleacetonitrile; Indol-3-ylacetonitrile; Indole-3-acetonitrile; (Indol-3-yl)acetonitrile
#
# cpd:C00060	Carboxylate; R-COOH; Monocarboxylate; Carboxylic acid

# %%
cpdString = set(pmt_countCpd) - (set(prm_countCpd)| set(pmg_countCpd))
for item in cpdString:
    print(kegg_list(item).read())
# Out:
# cpd:C08276	3-(Methylthio)propanoate; 3-(Methylthio)propionic acid; 3-Methylthiopropionate
#
# cpd:C00973	Cyclomaltodextrin; Cyclodextrin
#
# cpd:C00647	Pyridoxamine phosphate; Pyridoxamine 5-phosphate; Pyridoxamine 5'-phosphate
#
# cpd:C00195	N-Acylsphingosine; Ceramide; N-Acylsphing-4-enine; (4E)-Sphing-4-enine ceramide
#
# cpd:C01879	Pidolic acid; 5-Oxoproline; Pyroglutamic acid; 5-Pyrrolidone-2-carboxylic acid; Pyroglutamate; 5-Oxo-L-proline; L-Pyroglutamic acid; L-5-Pyrrolidone-2-carboxylic acid
#
# cpd:C01112	D-Arabinose 5-phosphate
#
# cpd:C01170	UDP-N-acetyl-D-mannosamine; UDP-N-acetyl-alpha-D-mannosamine
#
# cpd:C00018	Pyridoxal phosphate; Pyridoxal 5-phosphate; Pyridoxal 5'-phosphate; PLP
#
# cpd:C04478	3-Deoxy-D-manno-octulosonate 8-phosphate; 2-Dehydro-3-deoxy-D-octonate 8-phosphate
#
# cpd:C02538	Estrone 3-sulfate
#
# cpd:C02686	Galactosylceramide; Galactocerebroside; D-Galactosyl-N-acylsphingosine; Cerebroside; D-Galactosylceramide
#
# cpd:C00245	Taurine; 2-Aminoethanesulfonic acid; Aminoethylsulfonic acid
#
# cpd:C15606	1,2-Dihydroxy-5-(methylthio)pent-1-en-3-one
#
# cpd:C04582	S-Methyl-5-thio-D-ribulose 1-phosphate
#
# cpd:C01180	4-Methylthio-2-oxobutanoic acid; 4-Methylthio-2-oxobutanoate; 2-Keto-4-methylthiobutyric acid; 2-Oxo-4-methylthiobutanoate; 2-Oxo-4-methylthiobutanoic acid
#
# cpd:C00575	3',5'-Cyclic AMP; Cyclic adenylic acid; Cyclic AMP; Adenosine 3',5'-phosphate; Adenosine 3',5'-cyclic phosphate; cAMP
#
# cpd:C00534	Pyridoxamine; PM
#
# cpd:C00942	3',5'-Cyclic GMP; Guanosine 3',5'-cyclic monophosphate; Guanosine 3',5'-cyclic phosphate; Cyclic GMP; cGMP
#
# cpd:C01190	beta-D-Glucosyl-(1<->1)-ceramide; Glucosylceramide; Glucocerebroside; D-Glucosyl-N-acylsphingosine
#
# cpd:C00719	Betaine; Trimethylaminoacetate; Glycine betaine; N,N,N-Trimethylglycine; Trimethylammonioacetate
#
# cpd:C01026	N,N-Dimethylglycine; Dimethylglycine
#
# cpd:C00468	Estrone; 3-Hydroxy-1,3,5(10)-estratrien-17-one
#
# cpd:C06125	Sulfatide; Galactosylceramide sulfate; Cerebroside 3-sulfate
#
# cpd:C00721	Dextrin
#
# cpd:C15650	2,3-Diketo-5-methylthiopentyl-1-phosphate; 5-(Methylthio)-2,3-dioxopentyl phosphate
#
# cpd:C00519	Hypotaurine; 2-Aminoethanesulfinic acid

# %%
#what if I get slightly more complicated...in two, but not in all three?
cpdString = (set(pmg_countCpd) & set(pmt_countCpd)) - set(prm_countCpd)
len(cpdString)
for item in cpdString:
    print(kegg_list(item).read())
#obscure set of compounds...
# Out:
# cpd:C12834	2,5-Dichloro-carboxymethylenebut-2-en-4-olide
#
# cpd:C00870	4-Nitrophenol; p-Nitrophenol; PNP; Niphen; 4-Hydroxynitrobenzene
#
# cpd:C18309	3-Chloro-2-methyldienelactone
#
# cpd:C11832	Divinyl chlorophyllide a; 3,8-Divinyl chlorophyllide a
#
# cpd:C00110	Dolichyl phosphate; Dolichol phosphate
#
# cpd:C00966	2-Dehydropantoate
#
# cpd:C06329	2-Chloromaleylacetate
#
# cpd:C18243	2,3,5-Trichloromaleylacetate
#
# cpd:C16477	5-Fluoromuconolactone
#
# cpd:C01885	1-Acylglycerol; Glyceride; Monoglyceride; Monoacylglycerol; 1-Monoacylglycerol
#
# cpd:C16476	4-Fluoromuconolactone
#
# cpd:C18305	2-Chloro-5-methylmaleylacetate
#
# cpd:C04257	N-Acetyl-D-mannosamine 6-phosphate; N-Acetylmannosamine 6-phosphate
#
# cpd:C18242	2,3,5-Trichlorodienelactone
#
# cpd:C04706	cis-2-Chloro-4-carboxymethylenebut-2-en-1,4-olide; cis-2-Chlorodienelactone; cis-4-Carboxymethylene-2-chlorobut-2-en-4-olide
#
# cpd:C03360	4-Nitrophenyl phosphate
#
# cpd:C18310	3-Chloro-2-methylmaleylacetate
#
# cpd:C03862	Dolichyl phosphate D-mannose; Dolichyl D-mannosyl phosphate; Dolichyl beta-D-mannosyl phosphate
#
# cpd:C21333	8-Amino-3,8-dideoxy-D-manno-octulosonate; Kdo8N
#
# cpd:C12838	trans-4-Carboxymethylenebut-2-en-4-olide
#
# cpd:C20758	[Ribosomal protein S12]-3-methylthioaspartate
#
# cpd:C16487	Hydrofluoric acid; Hydrogen fluoride; Fluoride
#
# cpd:C18304	2-Chloro-5-methyl-cis-dienelactone
#
# cpd:C07090	Protoanemonin; 4-Methylenebut-2-en-4-olide; cis-4-Methylenebut-2-en-4-olide
#
# cpd:C21334	CMP-8-amino-3,8-dideoxy-beta-D-manno-octulosonate; CMP-Kdo8N
#
# cpd:C12835	2,5-Dichloro-4-oxohex-2-enedioate
#
# cpd:C01187	3-Deoxy-D-manno-octulosonate; Ketodeoxyoctonate; KDO; 2-Dehydro-3-deoxy-D-octonate; 3-Deoxy-D-manno-2-octulosonate; 3-Deoxyoctulosonic acid
#
# cpd:C20756	[Ribosomal protein S12]-L-aspartate
#
# cpd:C04157	tRNA containing N1-methylguanine; N1-Methylguanine in tRNA
#
# cpd:C07091	cis-Acetylacrylate
#
# cpd:C00422	Triacylglycerol; Triglyceride
#
# cpd:C04431	cis-4-Carboxymethylenebut-2-en-4-olide; 4-Carboxymethylenebut-2-en-4-olide
#
# cpd:C02222	2-Maleylacetate; 4-Oxohex-2-enedioate; Maleylacetate
#
# cpd:C04121	CMP-3-deoxy-D-manno-octulosonate; CMP-KDO; CMP-beta-KDO

# %%
#what if I get slightly more complicated...in two, but not in all three?
cpdString = (set(pmg_countCpd) & set(prm_countCpd)) - set(pmt_countCpd)
#len(cpdString)
for item in cpdString:
    print(kegg_list(item).read())
#obscure set of compounds...
# Out:
# cpd:C00315	Spermidine; N-(3-Aminopropyl)-1,4-butane-diamine
#
# cpd:C11544	2-O-(alpha-D-Mannosyl)-D-glycerate; alpha-Mannosylglycerate; 2-O-(alpha-D-Mannopyranosyl)-D-glycerate
#
# cpd:C00089	Sucrose; Cane sugar; Saccharose; 1-alpha-D-Glucopyranosyl-2-beta-D-fructofuranoside
#
# cpd:C06481	L-Seryl-tRNA(Sec)
#
# cpd:C00012	Peptide
#
# cpd:C01222	GDP-4-dehydro-6-deoxy-D-mannose; GDP-4-dehydro-6-deoxy-D-talose; GDP-4-oxo-6-deoxy-D-mannose; GDP-4-dehydro-D-rhamnose; GDP-4-keto-6-deoxy-D-mannose; GDP-4-dehydro-alpha-D-rhamnose; GDP-4-dehydro-6-deoxy-alpha-D-mannose
#
# cpd:C00750	Spermine; N,N'-Bis(3-aminopropyl)-1,4-butanediamine
#
# cpd:C01643	tRNA(His)
#
# cpd:C16633	5-Fluorouridine
#
# cpd:C16636	tRNA(Sec)
#
# cpd:C11516	2-(alpha-D-Mannosyl)-3-phosphoglycerate
#
# cpd:C02553	L-Seryl-tRNA(Ser)
#
# cpd:C02988	L-Histidyl-tRNA(His)
#
# cpd:C01650	tRNA(Ser)
#
# cpd:C16565	Aminopropylcadaverine
#
# cpd:C16634	5-Fluorouridine monophosphate

# %%
#what if I get slightly more complicated...in two, but not in all three?
cpdString = (set(prm_countCpd) & set(pmt_countCpd)) - set(pmg_countCpd)
#len(cpdString)
for item in cpdString:
    print(kegg_list(item).read())
#obscure set of compounds...
# Out:
# cpd:C05143	Dhurrin; (S)-4-Hydroxymandelonitrile beta-D-glucoside
#
# cpd:C00561	Mandelonitrile; Benzaldehyde cyanohydrin; (R)-Mandelonitrile
#
# cpd:C00637	Indole-3-acetaldehyde; 2-(Indol-3-yl)acetaldehyde; Indoleacetaldehyde
#
# cpd:C04554	3alpha,7alpha-Dihydroxy-5beta-cholestanate; 3alpha,7alpha-Dihydroxy-5beta-cholestanoate
#
# cpd:C01335	ROH
#
# cpd:C16502	Farnesoic acid; trans,trans-Farnesoic acid; (2E,6E)-Farnesoate
#
# cpd:C03461	2-trans,6-trans-Farnesal; trans,trans-Farnesal; Farnesal; (2E,6E)-3,7,11-Trimethyl-2,6,10-dodecatrienal; (2E,6E)-Farnesal
#
# cpd:C05130	Imidazole-4-acetaldehyde; Imidazole acetaldehyde
#
# cpd:C05445	3alpha,7alpha-Dihydroxy-5beta-cholestan-26-al
#
# cpd:C02835	Imidazole-4-acetate; Imidazoleacetic acid; 4-Imidazoleacetate
#
# cpd:C00395	Penicillin; Penam
#
# cpd:C00555	4-Aminobutyraldehyde; 4-Aminobutanal
#
# cpd:C01898	Cellodextrin; Cellooligosaccharide
#
# cpd:C11924	Perillic acid
#
# cpd:C00818	D-Glucarate; D-Glucaric acid; L-Gularic acid; D-Saccharic acid; D-Glucosaccharic acid; Glucaric acid; Glucarate
#
# cpd:C05810	2-Octaprenylphenol
#
# cpd:C00334	4-Aminobutanoate; 4-Aminobutanoic acid; 4-Aminobutyrate; 4-Aminobutyric acid; gamma-Aminobutyric acid; GABA
#
# cpd:C21214	Dimethylallyl phosphate
#
# cpd:C00811	4-Coumarate; p-Coumaric acid; trans-4-Hydroxycinnamate; trans-p-Hydroxycinnamate; 4-Hydroxycinnamic acid; 4-Hydroxycinnamate
#
# cpd:C05665	3-Aminopropanal; beta-Aminopropion aldehyde
#
# cpd:C06001	(S)-3-Hydroxyisobutyrate
#
# cpd:C05634	5-Hydroxyindoleacetaldehyde
#
# cpd:C01149	4-Trimethylammoniobutanal
#
# cpd:C06614	trans-3-Chloroacrylic acid
#
# cpd:C18796	(2R)-2-Hydroxy-2-methylbutanenitrile; 2-Hydroxy-2-methylbutanenitrile
#
# cpd:C05838	cis-2-Hydroxycinnamate; 2-Coumarinate
#
# cpd:C00071	Aldehyde; RCHO
#
# cpd:C02659	Acetone cyanohydrin; alpha-Hydroxyisobutyronitrile; 2-Hydroxy-2-methylpropanenitrile; 2-Methyllactonitrile; Acetone cyanhydrin; 2-Hydroxyisobutyronitrile
#
# cpd:C03742	(S)-4-Hydroxymandelonitrile
#
# cpd:C16348	cis-3-Chloroallyl aldehyde; cis-3-Chloro-2-propenal
#
# cpd:C05839	cis-beta-D-Glucosyl-2-hydroxycinnamate; beta-D-Glucosyl-2-coumarinate
#
# cpd:C01847	Reduced FMN; FMNH2
#
# cpd:C01197	Caffeate; Caffeic acid; 3,4-Dihydroxy-trans-cinnamate; trans-Caffeate; (2E)-3-(3,4-Dihydroxyphenyl)prop-2-enoate
#
# cpd:C16698	N-Acetylmuramic acid 6-phosphate; N-Acetylmuramate 6-phosphate; MurNAc 6-phosphate
#
# cpd:C00160	Glycolate; Glycolic acid; Hydroxyacetic acid
#
# cpd:C02946	4-Acetamidobutanoate; N4-Acetylaminobutanoate
#
# cpd:C02576	Perillyl aldehyde; Perillaldehyde
#
# cpd:C08334	Lotaustralin
#
# cpd:C08325	Amygdalin; (R)-Amygdalin; (R)-Amygdaloside; (R)-Laenitrile
#
# cpd:C00688	dTDP-4-dehydro-beta-L-rhamnose; dTDP-4-dehydro-6-deoxy-beta-L-mannose; dTDP-4-oxo-6-deoxy-L-mannose; dTDP-4-oxo-L-rhamnose
#
# cpd:C06755	Chloroacetic acid; Chloroethanoic acid
#
# cpd:C00433	2,5-Dioxopentanoate; 2-Oxoglutarate semialdehyde
#
# cpd:C05985	2-Propynal; 2-Propyn-1-al; Propiolaldehyde
#
# cpd:C06754	Chloroacetaldehyde; 2-Chloroethanal
#
# cpd:C03319	dTDP-L-rhamnose; dTDP-6-deoxy-L-mannose; dTDP-6-deoxy-beta-L-mannose; dTDP-beta-L-rhamnose
#
# cpd:C06002	(S)-Methylmalonate semialdehyde
#
# cpd:C11907	dTDP-4-oxo-6-deoxy-D-glucose; dTDP-4-dehydro-6-deoxy-D-glucose; dTDP-4-dehydro-6-deoxy-alpha-D-glucose; dTDP-4-dehydro-6-deoxy-alpha-D-glucopyranose; dTDP-4-oxo-6-deoxy-alpha-D-glucose; dTDP-4-dehydro-6-deoxy-alpha-D-galactose; dTDP-4-dehydro-6-deoxy-D-galactose; dTDP-6-deoxy-D-xylo-hexos-4-ulose; dTDP-6-deoxy-D-xylo-4-hexulose; 4,6-Dideoxy-4-oxo-dTDP-D-glucose
#
# cpd:C00185	Cellobiose; 1-beta-D-Glucopyranosyl-4-D-glucopyranose
#
# cpd:C00088	Nitrite
#
# cpd:C02670	D-Glucuronolactone; Glucurone; D-Glucurono-3,6-lactone; D-Glucurone
#
# cpd:C05807	2-Polyprenylphenol
#
# cpd:C05627	4-Hydroxystyrene; 4-Vinylphenol
#
# cpd:C06224	3,4-Dihydroxystyrene
#
# cpd:C05712	Cyanohydrin
#
# cpd:C21215	Prenylated FMNH2; Reduced prFMN
#
# cpd:C00963	beta-D-Glucoside
#
# cpd:C00804	Propynoate; Propiolic acid; Acetylenecarboxylic acid; Acetylenemonocarboxylate
#
# cpd:C05713	Cyanoglycoside; Cyanoglucoside
#
# cpd:C05635	5-Hydroxyindoleacetate
#
# cpd:C05936	N4-Acetylaminobutanal; 4-Acetamidobutanal
#
# cpd:C01594	Linamarin; Phaseolunatin
#
# cpd:C06615	cis-3-Chloroacrylic acid
#
# cpd:C01181	4-Trimethylammoniobutanoate; Butyro-betaine; gamma-Butyrobetaine
#
# cpd:C00844	Prunasin; (R)-Prunasin
#
# cpd:C02170	Methylmalonate; Methylmalonic acid
#
# cpd:C06613	trans-3-Chloroallyl aldehyde; trans-3-Chloro-2-propenal
#
# cpd:C06567	Penicilloic acid
#
# cpd:C00357	N-Acetyl-D-glucosamine 6-phosphate

# %%
kegg_link('reaction','C00315').read()
# Out:
# 'cpd:C00315\trn:R01914\ncpd:C00315\trn:R01915\ncpd:C00315\trn:R01917\ncpd:C00315\trn:R01918\ncpd:C00315\trn:R01919\ncpd:C00315\trn:R01920\ncpd:C00315\trn:R02869\ncpd:C00315\trn:R03899\ncpd:C00315\trn:R05329\ncpd:C00315\trn:R07300\ncpd:C00315\trn:R07477\ncpd:C00315\trn:R08983\ncpd:C00315\trn:R09076\ncpd:C00315\trn:R09077\ncpd:C00315\trn:R09081\ncpd:C00315\trn:R09531\ncpd:C00315\trn:R10347\ncpd:C00315\trn:R11154\ncpd:C00315\trn:R11159\ncpd:C00315\trn:R11199\ncpd:C00315\trn:R11200\n'

# %%
kegg_link('pathway','C00315').read()
# Out:
# 'cpd:C00315\tpath:map00330\ncpd:C00315\tpath:map00410\ncpd:C00315\tpath:map00480\ncpd:C00315\tpath:map00940\ncpd:C00315\tpath:map01100\ncpd:C00315\tpath:map02010\ncpd:C00315\tpath:map04976\n'

# %%
kegg_list('map00330').read()
# Out:
# 'path:map00330\tArginine and proline metabolism\n'

# %%
kegg_link('compound','map00260').read()
# Out:
# 'path:map00260\tcpd:C00011\npath:map00260\tcpd:C00014\npath:map00260\tcpd:C00022\npath:map00260\tcpd:C00037\npath:map00260\tcpd:C00048\npath:map00260\tcpd:C00049\npath:map00260\tcpd:C00065\npath:map00260\tcpd:C00078\npath:map00260\tcpd:C00097\npath:map00260\tcpd:C00101\npath:map00260\tcpd:C00109\npath:map00260\tcpd:C00114\npath:map00260\tcpd:C00143\npath:map00260\tcpd:C00168\npath:map00260\tcpd:C00188\npath:map00260\tcpd:C00197\npath:map00260\tcpd:C00213\npath:map00260\tcpd:C00258\npath:map00260\tcpd:C00263\npath:map00260\tcpd:C00300\npath:map00260\tcpd:C00430\npath:map00260\tcpd:C00441\npath:map00260\tcpd:C00546\npath:map00260\tcpd:C00576\npath:map00260\tcpd:C00581\npath:map00260\tcpd:C00631\npath:map00260\tcpd:C00719\npath:map00260\tcpd:C00740\npath:map00260\tcpd:C00986\npath:map00260\tcpd:C01005\npath:map00260\tcpd:C01026\npath:map00260\tcpd:C01102\npath:map00260\tcpd:C01242\npath:map00260\tcpd:C01726\npath:map00260\tcpd:C01888\npath:map00260\tcpd:C02051\npath:map00260\tcpd:C02291\npath:map00260\tcpd:C02737\npath:map00260\tcpd:C02855\npath:map00260\tcpd:C02972\npath:map00260\tcpd:C03082\npath:map00260\tcpd:C03194\npath:map00260\tcpd:C03232\npath:map00260\tcpd:C03283\npath:map00260\tcpd:C03508\npath:map00260\tcpd:C05519\npath:map00260\tcpd:C06231\npath:map00260\tcpd:C06442\npath:map00260\tcpd:C16432\npath:map00260\tcpd:C19929\n'

# %%
mtabPruned.head()
# Out:
#         Plimited_extracellular_s9301ax_50  Plimited_filter_s9301ax_50  \
# KEGG
# C00196                       0.000000e+00                         0.0
# C19675                       1.502503e-09                         0.0
# C08276                       0.000000e+00                         0.0
# C00141                       1.501737e-07                         0.0
# C00671                       0.000000e+00                         0.0
#
#         replete_extracellular_s9301ax_10  replete_extracellular_s9301ax_50  \
# KEGG
# C00196                      0.000000e+00                      0.000000e+00
# C19675                      7.559786e-09                      0.000000e+00
# C08276                      0.000000e+00                      0.000000e+00
# C00141                      1.269247e-07                      1.719122e-07
# C00671                      5.760611e-08                      1.074612e-07
#
#         replete_extracellular_s0801ax_10  replete_extracellular_s9313ax_5  \
# KEGG
# C00196                      0.000000e+00                     0.000000e+00
# C19675                      8.830372e-09                     0.000000e+00
# C08276                      0.000000e+00                     0.000000e+00
# C00141                      3.699587e-09                     1.385979e-06
# C00671                      0.000000e+00                     3.044114e-07
#
#         replete_extracellular_s9313ax_10  replete_filter_s9301ax_10  \
# KEGG
# C00196                      0.000000e+00               0.000000e+00
# C19675                      0.000000e+00               0.000000e+00
# C08276                      0.000000e+00               0.000000e+00
# C00141                      1.185440e-06               0.000000e+00
# C00671                      3.038489e-07               1.499082e-09
#
#         replete_filter_s9301ax_50  replete_filter_s0801ax_10  \
# KEGG
# C00196               0.000000e+00               0.000000e+00
# C19675               0.000000e+00               0.000000e+00
# C08276               0.000000e+00               0.000000e+00
# C00141               0.000000e+00               0.000000e+00
# C00671               1.232101e-09               2.171711e-09
#
#         replete_filter_s9313ax_5  replete_filter_s9313ax_10
# KEGG
# C00196              0.000000e+00               0.000000e+00
# C19675              0.000000e+00               0.000000e+00
# C08276              0.000000e+00               0.000000e+00
# C00141              0.000000e+00               0.000000e+00
# C00671              1.414847e-10               2.189543e-09

# %%
#oneStrain = 'pmg' #run for one strain that has been set above(options are 'pmg','pmt','prm')
useCO = mtabPruned.index
#these are the data (or ratios to plot...)
CO_values = mtabPruned.loc[:,'replete_filter_s9301ax_50']
fxn_plotPathway.gatherDetails('pmg00260','testingFolder',useCO,CO_values)

# %%
#oneStrain = 'pmg' #run for one strain that has been set above(options are 'pmg','pmt','prm')
useCO = mtabPruned.index
#these are the data (or ratios to plot...)
CO_values = mtabPruned.loc[:,'replete_filter_s0801ax_10']
fxn_plotPathway.gatherDetails('prm00260','testingFolder',useCO,CO_values)

# %%
trimReactions(a)
# Out:
# R03546
# R10657
# R02426
# R10079
# R00196
# R00578
# R10658
# R00956

# %%
for item in a:
    print(item)
# Out:
# R03546
# R10657
# R02426
# R10079
# R00196
# R00578
# R10658
# R00956

# %%
set(pmg_countRxn) - (set(prm_countRxn)| set(pmt_countRxn))
# Out:
# {'R00189',
#  'R00194',
#  'R00366',
#  'R00381',
#  'R00540',
#  'R00700',
#  'R01117',
#  'R01401',
#  'R01804',
#  'R01887',
#  'R02133',
#  'R02457',
#  'R02754',
#  'R02894',
#  'R02923',
#  'R03093',
#  'R03277',
#  'R03471',
#  'R03542',
#  'R04215',
#  'R04221',
#  'R04435',
#  'R04509',
#  'R04620',
#  'R05358',
#  'R05591',
#  'R05645',
#  'R05692',
#  'R07400',
#  'R07855',
#  'R09768',
#  'R09769',
#  'R09993',
#  'R10724',
#  'R10822',
#  'R10823'}

# %%
import dill                            #pip install dill --user

filename= 'globalsave.pkl'

dill.dump_session(filename)

# and to load the session again:

dill.load_session(filename)

# %%
#this will work to reload whatever I had
import dill
dill.load_session('globalsave.pkl')

# %%
#get all variables in the workspace
#whos

# %%
#leave debris below here for now, notebook will stop at the 'raise' command in the next cell to keep me from running cells 
#of code that are not meant to be connected

# %%
raise

# %%
##fussing around with specific pathways and compounds

# %%
oneMap = ''

# %%
#kegg_get(oneMap).read()
genes = getKfrom_ko(oneMap)
compounds = getCfrom_ko(oneMap)

setG = set(genes)
setC = set(compounds)
setT = set(useCO)
intCompounds = setC.intersection(setT)

useColors = pal.colorbrewer.diverging.PuOr_4.hex_colors
#useColors = pal.colorbrewer.diverging.RdYlBu_11.hex_colors

#set the color of the mtab based on its value, only scale the values from this particular pathway
useCOsubset = CO_values.loc[intCompounds]
cmin = useCOsubset.min() #find min and max...ignore NaN and inf for the moment
cmax = useCOsubset.replace([np.inf],np.nan).dropna(how = 'all').max()

size = 20 #increase the size of the compounds in the plots

pathway = KGML_parser.read(kegg_get(oneMap, "kgml")) #no choice in gene color: green

# %%
        dummy = useCOsubset.copy(deep = True)
        dummy.replace([np.inf],np.nan,inplace = True)
        for idx,item in enumerate(useCOsubset):
            if np.isnan(item):
                useCOsubset.iloc[idx] = 0
            elif np.isinf(item):
                useCOsubset.iloc[idx] = 10*cmax #make inf 10x the biggest value

        #now, find cmax again...use that downstream
        cmax = useCOsubset.replace([np.inf],np.nan).dropna(how = 'all').max()

        #use histogram to make the bins (complete hack)
        a,bin_edges = np.histogram(useCOsubset,bins = len(useColors)-3,range = (cmin,cmax))
        #now...put zero at beginning and inf at end
        #BUT - can actually have cases with values for all metabolites (novel concept)
        try:
            nz = useCOsubset.value_counts()[0] #count the number of zeros
            a = np.insert(a,0,nz)
            bin_edges = np.insert(bin_edges,0,0)
        except:
            pass
            
        try:
            nm = useCOsubset.value_counts()[cmax]
            a = np.append(a,nm)
            bin_edges = np.append(bin_edges,cmax)
        except:
            pass

        #then find the index for each number...this will be the index into useColors
        useIdx = np.digitize(useCOsubset,bin_edges)
        color_df = pd.DataFrame({'mtab': useCOsubset,'idx':useIdx})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-3ed9a0e71c0c> in <module>()
#      29
#      30 #then find the index for each number...this will be the index into useColors
# ---> 31 useIdx = np.digitize(useCOsubset,bin_edges)
#      32 color_df = pd.DataFrame({'mtab': useCOsubset,'idx':useIdx})
#
# ValueError: bins must be monotonically increasing or decreasing

# %%
# Change the colors of compounds
for element in pathway.compounds:
    for graphic in element.graphics:
        tc = element.name[4:10] #skip over the 'cpd:'
        if (tc in intCompounds):
            #in the pathway, set the color
            tempColor = useCOsubset.loc[tc]
            graphic.bgcolor = useColors[int(tempColor)] 
            graphic.width = size
            graphic.height = size

canvas = KGMLCanvas(oneMap, import_imagemap=True)
pdfName = 'mapWithColors_' + str(oneMap) + '.pdf'
canvas.draw('testingFolder' + '/' + pdfName)
pdfName = None #empty it in case that is where I am having issues
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-13007fbe585b> in <module>()
#       6             #in the pathway, set the color
#       7             tempColor = useCOsubset.loc[tc]
# ----> 8             graphic.bgcolor = useColors[int(tempColor)]
#       9             graphic.width = size
#      10             graphic.height = size
#
# ValueError: cannot convert float NaN to integer

# %%
#import plotByGroup
reload(plotByGroup)
# Out:
# <module 'plotByGroup' from 'C:\\Users\\krista\\Documents\\GitHub\\Pro_mtabs\\plotByGroup.py'>

# %%
#for oneGroup in unMetabolismGroups:
oneGroup = 'Carbohydrate metabolism'

# %%
plotByGroup.plotGroup(oneGroup,prunedBRITE,useCO,mtabPruned,oneStrain)
# Out:
# -----------------------------------------------------------------------
# TypeError                             Traceback (most recent call last)
# C:\Program Files\Anaconda3\lib\site-packages\numpy\ma\core.py in min(obj, axis, out, fill_value)
#    6294     try:
# -> 6295         return obj.min(axis=axis, fill_value=fill_value, out=out)
#    6296     except (AttributeError, TypeError):
#
# TypeError: _amin() got an unexpected keyword argument 'fill_value'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                             Traceback (most recent call last)
# <ipython-input-119-a607baa53136> in <module>()
# ----> 1 plotByGroup.plotGroup(oneGroup,prunedBRITE,useCO,mtabPruned,oneStrain)
#
# C:\Users\krista\Documents\GitHub\Pro_mtabs\plotByGroup.py in plotGroup(oneGroup, prunedBRITE, useCO, mtabPruned, oneStrain)
#      63     plt.title(oneGroup)
#      64     plt.xlabel('xlabel')
# ---> 65     plt.pcolor(gatherGroup,cmap = 'PRGn')
#      66     plt.yticks(np.arange(0.5, len(gatherGroup.index), 1), gatherGroup.index,fontsize = 8)
#      67     #plt.xticks(np.arange(0.5, len(gatherGroup.columns), 1), gatherGroup.columns,rotation = 45)
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\pyplot.py in pcolor(*args, **kwargs)
#    3081         ax.hold(hold)
#    3082     try:
# -> 3083         ret = ax.pcolor(*args, **kwargs)
#    3084     finally:
#    3085         ax.hold(washold)
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1816                     warnings.warn(msg % (label_namer, func.__name__),
#    1817                                   RuntimeWarning, stacklevel=2)
# -> 1818             return func(ax, *args, **kwargs)
#    1819         pre_doc = inner.__doc__
#    1820         if pre_doc is None:
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in pcolor(self, *args, **kwargs)
#    5245         collection.set_norm(norm)
#    5246         collection.set_clim(vmin, vmax)
# -> 5247         collection.autoscale_None()
#    5248         self.grid(False)
#    5249
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\cm.py in autoscale_None(self)
#     332         if self._A is None:
#     333             raise TypeError('You must first set_array for mappable')
# --> 334         self.norm.autoscale_None(self._A)
#     335         self.changed()
#     336
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\colors.py in autoscale_None(self, A)
#     980         ' autoscale only None-valued vmin or vmax'
#     981         if self.vmin is None and np.size(A) > 0:
# --> 982             self.vmin = ma.min(A)
#     983         if self.vmax is None and np.size(A) > 0:
#     984             self.vmax = ma.max(A)
#
# C:\Program Files\Anaconda3\lib\site-packages\numpy\ma\core.py in min(obj, axis, out, fill_value)
#    6297         # If obj doesn't have a min method or if the method doesn't accept
#    6298         # a fill_value argument
# -> 6299         return asanyarray(obj).min(axis=axis, fill_value=fill_value, out=out)
#    6300 min.__doc__ = MaskedArray.min.__doc__
#    6301
#
# C:\Program Files\Anaconda3\lib\site-packages\numpy\ma\core.py in min(self, axis, out, fill_value)
#    5467         if out is None:
#    5468             result = self.filled(fill_value).min(
# -> 5469                 axis=axis, out=out).view(type(self))
#    5470             if result.ndim:
#    5471                 # Set the mask
#
# C:\Program Files\Anaconda3\lib\site-packages\numpy\core\_methods.py in _amin(a, axis, out, keepdims)
#      27
#      28 def _amin(a, axis=None, out=None, keepdims=False):
# ---> 29     return umr_minimum(a, axis, None, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
#
# TypeError: unorderable types: float() <= str()

# %%
    #oneStrain = 'pmg'
    shortList = prunedBRITE.loc[(prunedBRITE['B']==oneGroup)] 
    onePath = shortList.loc[:,'map']
    onePath_ann = []
    for item in onePath:
        onePath_ann.append(oneStrain + item)

    gatherGroup = pd.DataFrame()
    for one in onePath_ann:
        #print(one)
        #not all pathways annotated in Prochlorococcus
        setKeep = 1
        try:
            kegg_get(one).read()
        except:
            #use the ko map if there is nothing species specific
            usePathway = 'ko' + one[3:8]
            setKeep = 0
            try:
                kegg_get(usePathway).read()
            except:
                pass
            
        if setKeep:
            usePathway = one
        
        try:
            mCpds = set(getCfrom_ko(usePathway))
        except:
            #no ko pathway either
            break
                          
        ProData= set(useCO)
        handh = mCpds.intersection(ProData)
        for cpd in handh:
            #print(cpd)
            #pdb.set_trace()
            tm = mtabPruned.loc[cpd,:]
            if (cpd in gatherGroup.index): 
                pass
            else: #only add the mtab if it is new...can have mtabs in multiple pathways
                gatherGroup = gatherGroup.append(tm)

# %%
gatherGroup
# Out:
#         Plimited_extracellular_s9301ax_50  Plimited_filter_s9301ax_50  extEff  \
# C00074                                0.0                         0.0     0.0
# C00111                                0.0                         0.0     0.0
# C00042                                0.0                         0.0     0.0
# C00122                                0.0                         0.0     0.0
# C00149                                0.0                         0.0     0.7
# C00026                                0.0                         0.0     0.0
# C00158                                0.0                         0.0     0.9
# C00092                                0.0                         0.0     0.0
# C02713                                0.0                         0.0     2.8
# C00352                                0.0                         0.0     0.0
# C01674                                0.0                         0.0     0.3
# C00140                                0.0                         0.0     0.0
# C00065                                0.0                         0.0     0.0
# C00064                                0.0                         0.0     0.0
# C00025                                0.0                         0.0     0.0
# C00334                                0.0                         0.0     0.0
#
#                          mtabNames  replete_extracellular_s0801ax_10  \
# C00074         phosphoenolpyruvate                               0.0
# C00111  dihydroxyacetone phosphate                               0.0
# C00042               succinic acid                               0.0
# C00122                fumaric acid                               0.0
# C00149                  malic acid                               0.0
# C00026     alpha-ketoglutaric acid                               0.0
# C00158                 citric acid                               0.0
# C00092                   glucose6P                               0.0
# C02713   n-acetyl muramic acid pos                               0.0
# C00352   D-glucosamine 6-phosphate                               0.0
# C01674              chitobiose pos                               0.0
# C00140        n-acetyl glucosamine                               0.0
# C00065                      serine                               0.0
# C00064                   glutamine                               0.0
# C00025               glutamic acid                               0.0
# C00334                        GABA                               0.0
#
#         replete_extracellular_s9301ax_10  replete_extracellular_s9301ax_50  \
# C00074                      0.000000e+00                               0.0
# C00111                      0.000000e+00                               0.0
# C00042                      2.812840e-10                               0.0
# C00122                      0.000000e+00                               0.0
# C00149                      0.000000e+00                               0.0
# C00026                      0.000000e+00                               0.0
# C00158                      0.000000e+00                               0.0
# C00092                      0.000000e+00                               0.0
# C02713                      0.000000e+00                               0.0
# C00352                      0.000000e+00                               0.0
# C01674                      0.000000e+00                               0.0
# C00140                      0.000000e+00                               0.0
# C00065                      0.000000e+00                               0.0
# C00064                      0.000000e+00                               0.0
# C00025                      0.000000e+00                               0.0
# C00334                      0.000000e+00                               0.0
#
#         replete_extracellular_s9313ax_10  replete_extracellular_s9313ax_5  \
# C00074                      0.000000e+00                     0.000000e+00
# C00111                      0.000000e+00                     0.000000e+00
# C00042                      4.626802e-10                     2.202084e-09
# C00122                      0.000000e+00                     0.000000e+00
# C00149                      0.000000e+00                     0.000000e+00
# C00026                      0.000000e+00                     0.000000e+00
# C00158                      0.000000e+00                     0.000000e+00
# C00092                      0.000000e+00                     0.000000e+00
# C02713                      0.000000e+00                     0.000000e+00
# C00352                      0.000000e+00                     0.000000e+00
# C01674                      0.000000e+00                     0.000000e+00
# C00140                      0.000000e+00                     0.000000e+00
# C00065                      0.000000e+00                     0.000000e+00
# C00064                      0.000000e+00                     0.000000e+00
# C00025                      0.000000e+00                     0.000000e+00
# C00334                      0.000000e+00                     0.000000e+00
#
#         replete_filter_s0801ax_10  replete_filter_s9301ax_10  \
# C00074               0.000000e+00               0.000000e+00
# C00111               6.225850e-09               4.823228e-09
# C00042               0.000000e+00               0.000000e+00
# C00122               0.000000e+00               0.000000e+00
# C00149               0.000000e+00               0.000000e+00
# C00026               0.000000e+00               0.000000e+00
# C00158               0.000000e+00               0.000000e+00
# C00092               0.000000e+00               0.000000e+00
# C02713               0.000000e+00               0.000000e+00
# C00352               0.000000e+00               0.000000e+00
# C01674               0.000000e+00               0.000000e+00
# C00140               0.000000e+00               0.000000e+00
# C00065               0.000000e+00               0.000000e+00
# C00064               3.644407e-08               2.487265e-09
# C00025               5.189948e-08               2.100895e-08
# C00334               0.000000e+00               0.000000e+00
#
#         replete_filter_s9301ax_50  replete_filter_s9313ax_10  \
# C00074               0.000000e+00               0.000000e+00
# C00111               0.000000e+00               1.225826e-09
# C00042               0.000000e+00               0.000000e+00
# C00122               0.000000e+00               0.000000e+00
# C00149               0.000000e+00               0.000000e+00
# C00026               1.106062e-08               5.207400e-08
# C00158               0.000000e+00               0.000000e+00
# C00092               0.000000e+00               5.723146e-09
# C02713               0.000000e+00               0.000000e+00
# C00352               0.000000e+00               0.000000e+00
# C01674               0.000000e+00               6.716598e-08
# C00140               0.000000e+00               0.000000e+00
# C00065               0.000000e+00               0.000000e+00
# C00064               0.000000e+00               4.834317e-09
# C00025               2.198301e-08               5.210153e-08
# C00334               0.000000e+00               0.000000e+00
#
#         replete_filter_s9313ax_5
# C00074              0.000000e+00
# C00111              0.000000e+00
# C00042              0.000000e+00
# C00122              0.000000e+00
# C00149              0.000000e+00
# C00026              2.511393e-08
# C00158              0.000000e+00
# C00092              0.000000e+00
# C02713              0.000000e+00
# C00352              0.000000e+00
# C01674              3.281535e-08
# C00140              0.000000e+00
# C00065              0.000000e+00
# C00064              0.000000e+00
# C00025              5.380081e-08
# C00334              0.000000e+00

# %%
type(gatherGroup)
# Out:
# pandas.core.frame.DataFrame

# %%
'C00074' in gatherGroup.index
# Out:
# True

# %%
if ('C00074' in gatherGroup.index):
    print('yes')
# Out:
# yes
